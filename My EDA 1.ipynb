# %% [markdown]
# # Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('supermarket_sales - supermarket_sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # Question
#
# As always, do your EDA, find me insights. I want a good section going over this, what you find me, i don't know. At the end, your mention some actionable items for a business, that it can do to perform better.
#
# ![](https://media.giphy.com/media/ukwPlCmJ5RmlqvQCpA/giphy.gif)
#
#
# ### Modeling
# - Fit a Simple Linear Regression Model, that tries to predict the ```Rating``` column with the help of the ```Total``` Column. We only have to use these 2 columns, nothing more.
#     - What was the training accuracy.
#     - What was the testing accuracy.
#
#
# ---
#
#
# - Make a python function, that takes ```Total``` as an input, and predicts what the ```Rating``` will be using your newly trained model to assist you !!
# - Just to be clear, your function will take 1 float value as an input and return back a float value as an output.

# %% [markdown]
# # Exploratory data analysis
# ![](https://ardas-it.com/uploads/images/blogs/giph.gif)

# %% [markdown]
# # General overview of the superstore

# %%
sns.lineplot(x="Hour",  y = 'Quantity',hue='Gender',data =df).set_title("Product Sales per Hour")
plt.show()

# %% [markdown]
# As evident from the graph above that the store experiences maximum number of sales in the afternoon around 2'0 clock and the
# least amount of sales somewhere in the evening around 6pm. The females tend to shop more in the morning and afternoon whereas men prefers to shop at mainly during the evening time. And as we all know that females tend to shop more than men for some some apparent reason which is very well depicted by the graph above.
# ![](https://cdn.ebaumsworld.com/mediaFiles/picture/2359627/84304758.gif)
# ![](https://media0.giphy.com/media/3ohhwFxJ6Nfifw6ovK/giphy.gif)

# %%
sns.countplot(x="Payment", hue = "Branch", data =df).set_title("Payment Channel by Branch") 
plt.show()

# %% [markdown]
# Credit card is the least prefered mode of payment prefered by the customers in all the branches A,B and C. One thing to note is that even in this digital age, most of the customer in Brach C tend to make cash payments. The shopkeerers should ensure that these basic activies go as digital as possible.
# ![](https://www.bing.com/th/id/OGC.021237e25d573a9022ebd9c476f42c48?pid=1.7&rurl=https%3a%2f%2fs3.scoopwhoop.com%2fanj2%2f5e7af843b704272a89c9c2d1%2f4d80ffac-d2f8-45b6-af0b-1ca9da8806ba.gif&ehk=Nve946CdiL83h%2fcaIGP8XbuQV71NOdlBVIuefloFl9w%3d)

# %%
sns.countplot(y ='Product line', hue = "Gender", data = df)
plt.show()

# %% [markdown]
# Males genrally tend to shop for health and beauty (maybe for their wifes), electronic accessories and home and lifestyle products where as females tend to
# shop for sports equipments, food and beverages and and fashion accessories.
# ![](https://media0.giphy.com/media/11gJIZpHOr9BJu/200.gif?cid=790b761196g0lc4t4on7rxvv27d02wis8j3tvn5lf9lzwx7j&rid=200.gif&ct=g)

# %% [markdown]
# # Now what's the issue

# %%
sns.displot(df, x="gross income", kind="ecdf")
plt.show()

# %% [markdown]
# From the graph above it is very evident that the gross income of the story is rising at a diminishing rate so clearly something's going wrong.
# ![](https://www.storypick.com/wp-content/uploads/2021/02/tenor1.gif)

# %% [markdown]
# # What could the store improve on?

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Hour'] = (df['Time']).dt.hour

# %%
sns.boxenplot(y = 'Product line', x = 'Quantity', data=df )
plt.show()

# %% [markdown]
# As evident from the plot above, Food and beverages and fashion accessories  have a lower average quantity then the rest of the
# products. This may be because the store may be giving discounts on the wholesale purchase of these products.
# ![](https://media.tenor.co/images/cc52d88c5738d491c2175c408d90d1dc/raw)

# %%
sns.countplot(y = 'Product line', data=df, order = df['Product line'].value_counts().index )
plt.show()

# %% [markdown]
# As we saw in the boxen plot that we made, health and beauty and home and lifestyle have a higher average quantity than
# food and beverages but the number of customers that are puchasing products in these categories are very less, the store manager
# shoud give discounts even on the retail purchase of these product cateogries as there is already a huge demand for these products among customers and espically among men. Giving such discounts will increase the profits as these products are already in demand and customers are so desperate to purchase these products that they are purchasing it in bulk to get the wholesale discount. So
# as mentioned above that if the store maneger starts giving discounts even on small quantity purchase of these products that they can increase their profits.
# ![](https://media.tenor.com/L5ixYM94LJQAAAAC/shaquille-o-neal-excited.gif)

# %% [markdown]
# # We need to keep in mind that the businees operates in 3 locations, lets have a location wise analysis to better understand what's going on

# %%
df_Yangon=df[df['City']=='Yangon']
df_Naypyitaw=df[df['City']=='Naypyitaw']
df_Mandalay=df[df['City']=='Mandalay']

# %%
sns.lineplot(x="Hour",  y = 'Quantity',hue='City',data =df).set_title("Product Sales per Hour")
plt.show()

# %% [markdown]
# In the above chart we can deduce that Mandalay is recording the highest sales in the afternoon among all the 3 locations
# as well as the lowest sales at the time of closure of the shop around 8 in the evening,which means that  majority of the customer in Mandalay prefer shopping in the afternoon and very few prefer to shop in the evening.This could mean that people residing in Mandlay are early sleepers and do not prefer an outing in the evening time.To tackle this, the shopkeepers can start providing home delivery services to their customers in the night time.
#
# Similarly if we talk about Naypyitaw, it is the only city in which there are two peak hours, one at 2 in the afternoon and the other one at 7 in the evening. So the shopkeepers should make sure that the shop in Naypyitaw in fully staffed in these peak hours.
#
# Yagon is the only city where the peak hour is only in the evening. This indicates that customers in Yagon only prefer late night shopping as they might be busy throughout the day. Thus the shopkeepers must make sure that they have sufficient staff in the night duty to avoid understaffing which may further affect sales.

# %%
a=df_Yangon.groupby('Customer type')
df_Yangon['Customer type'].value_counts().plot(kind='bar')

# %%
df_Yangon['Gender'].value_counts().plot(kind='pie')
plt.show()

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2023-04-01 13:08:00      Ewallet  522.83                 4.761905
# ...

# %%
df_Naypyitaw['Gender'].value_counts().plot(kind='pie')
plt.show()

# %%
df_Mandalay['Gender'].value_counts().plot(kind='pie')
plt.show()

# %% [markdown]
# Although the shop that they have in Yangona and Mandalay have equal gender engagement but the shop that they have in Naypyitaw is more female dominated, they can focus more on the men section to balance out the gender
# disparity.
# ![](https://static01.nyt.com/images/2018/01/09/us/mtm-readerart-9-LNmetoo/mtm-readerart-9-master768.gif)

# %% [markdown]
# # Now lets start creating the model:
# ![](https://i.imgflip.com/328qto.gif)

# %%
sns.pairplot(df)

# %%
# Sperating data into X and Y
X = df['Total']
X.head()
# Out:
# 0    548.9715
# 1     80.2200
# 2    340.5255
# 3    489.0480
# 4    634.3785
# Name: Total, dtype: float64

# %%
# Sperating data into X and Y
y = df['Rating']
y.head()
# Out:
# 0    9.1
# 1    9.6
# 2    7.4
# 3    8.4
# 4    5.3
# Name: Rating, dtype: float64

# %%
# Import train-test scikit learn
from sklearn.model_selection import train_test_split

# %%
# Split the data for train and test 
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.75,random_state=100)

# %%
#Since x_train is a series without a column so we only get a sigle value. Meaning that X_train has 750 rows(since we have chosen
#our training size as 75%) and 0 columns.

X_train.shape
# Out:
# (750,)

# %%
X_train.values.reshape(-1,1)
# Out:
# array([[ 603.876 ],
#        [ 786.618 ],
#        [  57.876 ],
#        [  33.495 ],
#        [ 338.2155],
#        [ 130.032 ],
#        [ 688.716 ],
#        [ 196.14  ],
#        [ 667.38  ],
#        [ 321.111 ],
#        [ 703.752 ],
#        [  78.0045],
#        [ 282.492 ],
#        [ 203.553 ],
#        [  33.936 ],
#        [ 384.72  ],
#        [ 408.408 ],
#        [  91.8225],
#        [ 926.9505],
#        [ 181.44  ],
#        [ 431.256 ],
#        [ 860.685 ],
#        [ 462.21  ],
#        [ 137.004 ],
#        [ 517.965 ],
#        [  36.5505],
#        [ 131.922 ],
#        [ 253.512 ],
#        [ 152.712 ],
#        [  93.744 ],
#        [ 362.712 ],
#        [ 121.569 ],
#        [ 365.904 ],
#        [ 293.139 ],
#        [ 110.0925],
#        [ 629.8425],
#        [ 588.42  ],
#        [ 194.985 ],
#        [ 246.4875],
#        [ 224.4375],
#        [ 503.7375],
#        [ 874.125 ],
#        [  16.107 ],
#        [ 253.26  ],
#        [  30.219 ],
# ...

# %%
X_train.values.reshape(-1,1).shape
# Out:
# (750, 1)

# %%
#Overwriting X_train and X_test after adding a column.
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %% [markdown]
# # Time to fit the model:

# %%
# Importing Linear Regression model from scikit learn
from sklearn.linear_model import LinearRegression

# %%
# Initializing.
lr = LinearRegression()

# %%
# Fitting the model:
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[1050.0]])
# Out:
# array([6.66180375])

# %%
# Predicting the ratings for the Test values
y_pred_test = lr.predict(X_test)

# %%
y_pred_test
# Out:
# array([6.86955398, 6.98368946, 7.04537076, 7.0800936 , 7.00261141,
#        6.89492214, 7.00088505, 7.03035226, 6.71396879, 6.97766846,
#        6.95983505, 6.83142519, 6.95885706, 6.99337155, 6.79047299,
#        6.92224628, 7.00274748, 6.83955099, 7.00250936, 7.08187524,
#        6.89379533, 7.03435351, 6.83209277, 7.07394503, 7.04037026,
#        7.02014717, 7.0458555 , 7.03872044, 6.942716  , 6.92584358,
#        6.99710916, 6.89852794, 7.07626243, 7.02668693, 7.0567622 ,
#        6.8371613 , 7.0290171 , 7.07178495, 6.91735634, 6.9925679 ,
#        6.91682483, 6.89080183, 6.90223579, 6.78974162, 7.02503711,
#        6.87128034, 7.05229322, 7.04041279, 7.04554935, 6.86260601,
#        6.95207918, 6.81084066, 6.9220677 , 6.88309273, 7.06190727,
#        6.75126841, 6.74875541, 7.05269292, 7.0706794 , 6.76769862,
#        6.94483356, 7.03912864, 6.92545239, 6.97395635, 6.85376584,
#        7.08107159, 6.96368748, 6.98011768, 6.83027286, 7.07550556,
# ...

# %%
y_test
# Out:
# 249    4.2
# 353    4.8
# 537    6.9
# 424    5.0
# 564    9.0
#       ...
# 662    5.9
# 454    4.7
# 474    6.6
# 917    6.8
# 849    4.2
# Name: Rating, Length: 250, dtype: float64

# %% [markdown]
# # Checking the test accuracy.

# %%
# Importing metrics for the evaluation of the model
from sklearn.metrics import r2_score,mean_squared_error

# %%
# calculate Mean square error
mean_squared_error(y_test,y_pred_test)
# Out:
# 3.0075908719689988

# %%
mse = mean_squared_error(y_test,y_pred_test)

# %%
# Calculate R square vale
r2_score(y_test,y_pred_test)
# Out:
# -0.008547960151905842

# %%
x_range = [i for i in range(len(y_test))]

# %%
plt.xlabel('Total')
plt.ylabel('Ratings')
plt.title('Prediction')

plt.plot(x_range,y_test)
plt.plot(x_range,y_pred_test)

# Function add a legend  
plt.legend(["Real", "Predicted"])

# %%
plt.show()

# %%
# Create a list of values in the best fit line
abline_values = [lr.coef_ * i + lr.intercept_ for i in range(0,15,1)]
x = [i for i in range(0,15,1)]

# Plot the best fit line over the actual values

plt.plot(x, abline_values, 'b')


plt.scatter(df['Total'],df['Rating'])

plt.title('Our Fitted Line')
plt.show()

# %% [markdown]
# # Checking the train accuracy.

# %%
# Predicting the ratings for the train values
y_pred_train = lr.predict(X_train)

# %%
y_train
# Out:
# 786    5.5
# 152    7.4
# 925    9.0
# 501    9.1
# 920    5.1
#       ...
# 855    4.2
# 871    9.6
# 835    5.8
# 792    4.9
# 520    7.7
# Name: Rating, Length: 750, dtype: float64

# %%
# calculate Mean square error
mean_squared_error(y_train,y_pred_train)
# Out:
# 2.9285116449354973

# %%
mse = mean_squared_error(y_train,y_pred_train)

# %%
# Calculate R square vale
r2_score(y_train,y_pred_train)
# Out:
# 0.0034309138103360004

# %%
x_range = [i for i in range(len(y_train))]

# %%
plt.xlabel('Total')
plt.ylabel('Ratings')
plt.title('Prediction')

plt.plot(x_range,y_train)
plt.plot(x_range,y_pred_train)

# Function add a legend  
plt.legend(["Real", "Predicted"])

# %%
plt.show()

# %% [markdown]
# # Creating a single function for all this hassle:

# %%
def my_function(x):
    temp=[]
    temp.append(lr.predict([[x]]))
    return temp

# %%
my_function(1050.0)
# Out:
# [array([6.66180375])]

# %% [markdown]
# R squared: It is the variance explained by the new variable which was earlier unexplained by the previous.

# %% [markdown]
# ![](https://c.tenor.com/wPXgUUpy2scAAAAC/carryminati-ajey-nagar.gif)
